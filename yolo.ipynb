# %%
from ultralytics import YOLO
import torch
from PIL import Image

# %%
device = (
    "cuda"
    if torch.cuda.is_available()
    else "mps"
    if torch.backends.mps.is_available()
    else "cpu"
)
print(f"Using {device} device")
# Out:
# Using cuda device

# %%
model = YOLO('yolov8n.pt')
model
# Out:
# ...
# 100%|██████████| 6.23M/6.23M [00:00<00:00, 14.5MB/s]
# YOLO(
#   (model): DetectionModel(
#     (model): Sequential(
#       (0): Conv(
#         (conv): Conv2d(3, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(16, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (1): Conv(
#         (conv): Conv2d(16, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (2): C2f(
#         (cv1): Conv(
#           (conv): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
# ...

# %%
results = model.train(data='data.yaml', epochs=1, imgsz=256, device=device, plots=True)
# Out:
# New https://pypi.org/project/ultralytics/8.1.23 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.1.20 🚀 Python-3.11.6 torch-2.2.0+cu121 CUDA:0 (NVIDIA GeForce RTX 4060, 8188MiB)
# ...

# %%
results = model.val(device=device, plots=True)
# Out:
# Ultralytics YOLOv8.1.20 🚀 Python-3.11.6 torch-2.2.0+cu121 CUDA:0 (NVIDIA GeForce RTX 4060, 8188MiB)
# Model summary (fused): 168 layers, 3006818 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning C:\Users\Max\Documents\prog-ipynb\worldskills\valid\labels.cache... 780 images, 7 backgrounds, 1 corrupt: 100%|██████████| 780/780 [00:00<?, ?it/s]
# val: WARNING ⚠️ C:\Users\Max\Documents\prog-ipynb\worldskills\valid\images\gallery_used-car-carlist-toyota-hiace-van-malaysia_7200061_755081379_v1sm_jpg.rf.c09253dad7c35caee71a1366c0b0e11d.jpg: ignoring corrupt image/label: labels require 5 columns, 4 columns detected
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 49/49 [00:04<00:00, 11.92it/s]
#                    all        779       1152      0.554       0.69      0.666      0.486
#                   five        779        136       0.64      0.846       0.82      0.553
# ...

# %%
Image.open('runs/detect/train/results.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2400x1200>

# %%
Image.open('runs/detect/train/confusion_matrix.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=3000x2250>

# %%
model = YOLO('runs/detect/train/weights/best.pt')
model
# Out:
# YOLO(
#   (model): DetectionModel(
#     (model): Sequential(
#       (0): Conv(
#         (conv): Conv2d(3, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(16, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (1): Conv(
#         (conv): Conv2d(16, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (2): C2f(
#         (cv1): Conv(
#           (conv): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(48, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
# ...

# %%
results = model.predict('path', imgsz=64, device=device, save=True, save_txt=True)
# Out:
# image 1/1 C:\Users\Max\Documents\prog-ipynb\worldskills\path\Снимок экрана 2024-03-01 184405.png: 64x64 2 ones, 14.0ms
# Speed: 2.0ms preprocess, 14.0ms inference, 16.0ms postprocess per image at shape (1, 3, 64, 64)
# Results saved to runs\detect\predict
# 1 label saved to runs\detect\predict\labels
